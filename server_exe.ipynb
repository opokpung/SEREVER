# %% [markdown]
# <a href="https://colab.research.google.com/github/opokpung/SEREVER/blob/main/server_exe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# ███╗   ███╗██╗███╗   ██╗███████╗ ██████╗ ██████╗ ██╗      █████╗ ██████╗
# ████╗ ████║██║████╗  ██║██╔════╝██╔════╝██╔═══██╗██║     ██╔══██╗██╔══██╗
# ██╔████╔██║██║██╔██╗ ██║█████╗  ██║     ██║   ██║██║     ███████║██████╔╝
# ██║╚██╔╝██║██║██║╚██╗██║██╔══╝  ██║     ██║   ██║██║     ██╔══██║██╔══██╗
# ██║ ╚═╝ ██║██║██║ ╚████║███████╗╚██████╗╚██████╔╝███████╗██║  ██║██████╔╝
# ╚═╝     ╚═╝╚═╝╚═╝  ╚═══╝╚══════╝ ╚═════╝ ╚═════╝ ╚══════╝╚═╝  ╚═╝╚═════╝
# ```
# Create a Minecraft Server on Google Colab!
#
# The script below will initiate your server. First, you will need to create the server to be able to use it - don't worry, the scripts below will do the majority of the work for you. Perhaps you want to change the server's region, check below.
#
# Original: https://github.com/thecoder-001/MineColab

# %% [markdown]
# # **1º Create the Server (Only do this the first time)**
#
# The code below will create your server and accept the EULA. When you use these scripts, your server will be ready to start.

# %% [markdown]
# **Download the Minecraft Server**
#
# The code below will download Paper, a type of high-performance Vanilla server that allows the use of plugins. If you want to use another type of server.jar, put it in the Drive folder manually.
#
# The server files will be saved on your Google Drive (in the Google account you choose or are using).

# %%
# Change "1.20.1" to the desired version.
# Available tested versions:
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8
# Newer versions might work too, however this isn't guaranteed.

version = '1.20.4'

# Choose server type. Currently available versions:
# - paper (Most vanilla. It's the same as SPIGOT, bukkit, etc.)
# - forge (For using MODS. It's basically FORGE) [Note, installation takes approximately 10-15 minutes, wait for "COMPLETED" after executing the first step.]
# - fabric (For playing Fabric. It's an alternative to Forge)

server_type = 'paper'

# Print experimental build warning -- no longer needed
# if version == '1.18' and server_type == 'paper':
#  print("<!> Paper 1.18 builds are still experimental. Make regular Backups!")

from google.colab import drive
import requests
import json

drive.mount('/content/drive')

# Create the directory which will be used for the server
! mkdir "/content/drive/My Drive/Minecraft-server"
# %cd "/content/drive/My Drive/Minecraft-server"

# Internal init...

a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)
#print(a.json()["builds"][-1])
b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))
#print(b.json()["downloads"]["application"]["name"])
print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])

paperURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

forgeURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge-installer.jar'}
url = {
    'paper': (paperURL),
    'fabric': 'https://maven.fabricmc.net/net/fabricmc/fabric-installer/0.7.4/fabric-installer-0.7.4.jar',
    'forge': (forgeURL)
    }

print('Downloading to Google Drive...')

r = requests.get(url[server_type])

if r.status_code == 200:
  with open('/content/drive/My Drive/Minecraft-server/' + jar_name[server_type], 'wb') as f:
    f.write(r.content)
else:
  print('Error '+ str(r.status_code) + '! Most likely you entered an unsupported version. Try running the code again if you think that shouldn\'t have happened.')

# Running specific install path.
if server_type == 'fabric':
  # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
  # %cd "/content/drive/My Drive/Minecraft-server"
  # !java -jar forge-installer.jar --installServer

# Saving config
colabconfig = {"server_type": server_type,
               "server_version": version}
json.dump(colabconfig, open("colabconfig.json",'w'))

print('Completed!')  # todo: Would show even after erroring.

# Please read the file stored in your server folder before running this command.
# Also, go to https://www.minecraft.net/en-us/eula to read Minecraft's EULA.

# Make sure Drive is mounted
from google.colab import drive
drive.mount('/content/drive')

# %cd "/content/drive/My Drive/Minecraft-server"
# !echo "eula=true" >> eula.txt
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Minecraft-server
# https://papermc.io/api/v2/projects/paper/versions/1.20.4/builds/497/downloads/paper-1.20.4-497.jar
# Downloading to Google Drive...
# Completed!
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Minecraft-server

# %% [markdown]
# # **-> Start the Minecraft server - Use this whenever you want to open it.**
#
# You can change the REGION in the code below; this is important for LAG and PING. Use regions closest to you. The default region is the United States, which is not recommended for countries in South America or Spain. For these, you can use regions like 'sa' (Brazil) and 'eu' (Europe). You can change it in the code below where indicated.
#
# **IMPORTANT:**
#
# The IP will change every time you restart the server.
# You need to enter your Ngrok TOKEN below. Visit https://dashboard.ngrok.com/auth to obtain your token (you need to have an account created on Ngrok).
# To enter a command through the console, you can do it here. Basically, the section below will be your console (where you will enter commands and see logs).
# It is advisable to keep the Google Colab tab open so that the server does not close. It may ask you to solve a captcha from time to time.

# %%
import os
import re
import json
import glob

# Update the package lists
# !sudo apt update &>/dev/null && echo "apt cache successfully updated" || echo "apt cache update failed, you might receive stale packages"

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Change directory to the Minecraft server folder on Google Drive
# %cd "/content/drive/My Drive/Minecraft-server"
# !ls #list the directory contents (to verify that working directory was changed)

# Import config file.
if os.path.isfile("colabconfig.json"):
  colabconfig = json.load(open("colabconfig.json"))
else:
  colabconfig = {"server_type": "generic"} # using default, if config doesn't exist.
  json.dump(colabconfig, open("colabconfig.json",'w'))

# Install OpenJDK 17
# !wget -qO - https://adoptopenjdk.jfrog.io/adoptopenjdk/api/gpg/key/public | sudo apt-key add -
# !sudo add-apt-repository --yes https://adoptopenjdk.jfrog.io/adoptopenjdk/deb/ &>/dev/null || echo "Failed to add repo. Still can be ignored if openjdk17 gets installed."
if colabconfig["server_type"] == "forge":
   version = colabconfig["server_version"]
   if colabconfig["server_version"] < "1.17":
    # !sudo apt-get install openjdk-15-jre-headless &>/dev/null && echo "Yay! Openjdk15 has been successfully installed." || echo "Failed to install OpenJdk15."
   else:
    # !sudo apt-get install openjdk-17-jre-headless &>/dev/null && echo "Yay! Openjdk17 has been successfully installed." || echo "Failed to install OpenJdk17."
else:
  # !sudo apt-get install openjdk-17-jre-headless &>/dev/null && echo "Yay! Openjdk17 has been successfully installed." || echo "Failed to install OpenJdk17."

#Perform java version check
java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'
if java_ver[0] == "17" :
  print("Openjdk17 is working correctly, you are good to go.")
else:
  print("Openjdk17 doesn't seem to be installed or isn't working, falling back to java", java_ver[0], ". You might experience reduced performance. Minecraft 1.17 and above might fail to launch.")

# Server jar names.
jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar'}
jar_name = jar_list[colabconfig["server_type"]]

# Java arguments.
if colabconfig["server_type"] == "paper":
  server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"
else:
  server_flags = "" # aiker's flags might negatively impact performance on non-paper servers.
memory_allocation = "-Xms8704M -Xmx8704M"

# Choose the tunnel service you want to use
# Available options: ngrok, argo, playit
tunnel_service = "playit"
print("Using", tunnel_service)

# !java $memory_allocation $server_flags -jar $jar_name nogui
# Out:
# apt cache successfully updated
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Minecraft-server
# banned-ips.json      commands.yml  logs		    server.properties	  whitelist.json
# banned-players.json  config	   ops.json	    spigot.yml		  world
# bukkit.yml	     eula.txt	   permissions.yml  usercache.json	  world_nether
# cache		     help.yml	   plugins	    version_history.json  world_the_end
# colabconfig.json     libraries	   server.jar	    versions
# Yay! Openjdk17 has been successfully installed.
# Openjdk17 is working correctly, you are good to go.
# Using playit
# Starting org.bukkit.craftbukkit.Main
# System Info: Java 17 (OpenJDK 64-Bit Server VM 17.0.10+7-Ubuntu-122.04.1) Host: Linux 6.1.85+ (amd64)
# Loading libraries, please wait...
# [00:53:25 ERROR]: [DirectoryProviderSource] Error loading plugin: java.lang.IllegalArgumentException: Directory 'plugins/fabric-api-0.99.4+1.20.6.jar' does not contain a paper-plugin.yml or plugin.yml! Could not determine plugin type, cannot load a plugin from it!
# java.lang.RuntimeException: java.lang.IllegalArgumentException: Directory 'plugins/fabric-api-0.99.4+1.20.6.jar' does not contain a paper-plugin.yml or plugin.yml! Could not determine plugin type, cannot load a plugin from it!
# 	at io.papermc.paper.plugin.provider.source.FileProviderSource.registerProviders(FileProviderSource.java:70) ~[paper-1.20.4.jar:git-Paper-497]
# 	at io.papermc.paper.plugin.provider.source.DirectoryProviderSource.registerProviders(DirectoryProviderSource.java:47) ~[paper-1.20.4.jar:git-Paper-497]
# 	at io.papermc.paper.plugin.provider.source.DirectoryProviderSource.registerProviders(DirectoryProviderSource.java:17) ~[paper-1.20.4.jar:git-Paper-497]
# 	at io.papermc.paper.plugin.util.EntrypointUtil.registerProvidersFromSource(EntrypointUtil.java:15) ~[paper-1.20.4.jar:git-Paper-497]
# 	at io.papermc.paper.plugin.PluginInitializerManager.load(PluginInitializerManager.java:101) ~[paper-1.20.4.jar:git-Paper-497]
# 	at net.minecraft.server.Main.main(Main.java:120) ~[paper-1.20.4.jar:git-Paper-497]
# 	at org.bukkit.craftbukkit.Main.main(Main.java:326) ~[paper-1.20.4.jar:git-Paper-497]
# 	at io.papermc.paperclip.Paperclip.lambda$main$0(Paperclip.java:42) ~[app:?]
# 	at java.lang.Thread.run(Thread.java:840) ~[?:?]
# Caused by: java.lang.IllegalArgumentException: Directory 'plugins/fabric-api-0.99.4+1.20.6.jar' does not contain a paper-plugin.yml or plugin.yml! Could not determine plugin type, cannot load a plugin from it!
# 	... 9 more
# [00:53:33 INFO]: Environment: Environment[sessionHost=https://sessionserver.mojang.com, servicesHost=https://api.minecraftservices.com, name=PROD]
# [00:53:40 INFO]: Loaded 1174 recipes
# [00:53:40 INFO]: Loaded 1271 advancements
# [00:53:41 INFO]: Starting minecraft server version 1.20.4
# [00:53:41 WARN]: ****************************
# [00:53:41 WARN]: YOU ARE RUNNING THIS SERVER AS AN ADMINISTRATIVE OR ROOT USER. THIS IS NOT ADVISED.
# [00:53:41 WARN]: YOU ARE OPENING YOURSELF UP TO POTENTIAL RISKS WHEN DOING THIS.
# [00:53:41 WARN]: FOR MORE INFORMATION, SEE https://madelinemiller.dev/blog/root-minecraft-server/
# [00:53:41 WARN]: ****************************
# [00:53:41 INFO]: Loading properties
# [00:53:41 INFO]: This server is running Paper version git-Paper-497 (MC: 1.20.4) (Implementing API version 1.20.4-R0.1-SNAPSHOT) (Git: d8d54d9 on ver/1.20.4)
# [00:53:43 INFO]: Server Ping Player Sample Count: 12
# [00:53:43 INFO]: Using 4 threads for Netty based IO
# [00:53:43 WARN]: [!] The timings profiler has been enabled but has been scheduled for removal from Paper in the future.
#     We recommend installing the spark profiler as a replacement: https://spark.lucko.me/
#     For more information please visit: https://github.com/PaperMC/Paper/issues/8948
# [00:53:44 INFO]: [ChunkTaskScheduler] Chunk system is using 1 I/O threads, 1 worker threads, and gen parallelism of 1 threads
# [00:53:45 INFO]: Default game type: SURVIVAL
# [00:53:45 INFO]: Generating keypair
# [00:53:46 INFO]: Starting Minecraft server on *:25565
# [00:53:46 INFO]: Using epoll channel type
# [00:53:46 INFO]: Paper: Using libdeflate (Linux x86_64) compression from Velocity.
# [00:53:46 INFO]: Paper: Using OpenSSL 3.0.x (Linux x86_64) cipher from Velocity.
# [00:53:47 WARN]: [org.bukkit.craftbukkit.v1_20_R3.legacy.CraftLegacy] Initializing Legacy Material Support. Unless you have legacy plugins and/or data this is a bug!
# [00:53:58 WARN]: Legacy plugin SetLobby v1.1 does not specify an api-version.
# [00:53:58 INFO]: [ViaVersion] Loading server plugin ViaVersion v4.10.2
# [00:53:58 INFO]: [ViaVersion] ViaVersion 4.10.2 is now loaded. Registering protocol transformers and injecting...
# [00:53:59 INFO]: [ViaVersion] Loading block connection mappings ...
# [00:53:59 INFO]: [ViaVersion] Using FastUtil Long2ObjectOpenHashMap for block connections
# [00:54:00 INFO]: [ViaBackwards] Loading translations...
# [00:54:00 INFO]: [ViaBackwards] Registering protocols...
# [00:54:01 INFO]: [floodgate] Loading server plugin floodgate v2.2.3-SNAPSHOT (b107-c4a4487)
# [00:54:02 INFO]: [floodgate] Took 1,429ms to boot Floodgate
# [00:54:02 INFO]: [ViaBackwards] Loading server plugin ViaBackwards v4.10.2
# [00:54:02 INFO]: [playit-gg] Loading server plugin playit-gg v0.1.4
# [00:54:02 INFO]: [FastChunkPregenerator] Loading server plugin FastChunkPregenerator v2.0.9-SNAPSHOT
# [00:54:02 INFO]: [SkinsRestorer] Loading server plugin SkinsRestorer v15.0.13
# [00:54:02 INFO]: [GriefPrevention] Loading server plugin GriefPrevention v16.18.3
# [00:54:02 INFO]: [SetLobby] Loading server plugin SetLobby v1.1
# [00:54:02 INFO]: [ClearLag] Loading server plugin ClearLag v3.2.2
# [00:54:02 INFO]: [SimpleTpa] Loading server plugin SimpleTpa v7.0
# [00:54:02 INFO]: [Geyser-Spigot] Loading server plugin Geyser-Spigot v2.3.1-SNAPSHOT
# [00:54:04 INFO]: [Geyser-Spigot] Loading extensions...
# [00:54:04 INFO]: [Geyser-Spigot] Loaded 0 extension(s)
# [00:54:04 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [00:54:04 INFO]: [SkinsRestorer] Enabling SkinsRestorer v15.0.13
# [00:54:07 INFO]: [SkinsRestorer] Running on Minecraft 1.20.4.
# [00:54:07 INFO]: [SkinsRestorer] Using paper join listener!
# [00:54:07 INFO]: [SkinsRestorer] Floodgate skin listener registered
# [00:54:07 WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [00:54:07 WARN]: The server will make no attempt to authenticate usernames. Beware.
# [00:54:07 WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [00:54:07 WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [00:54:07 INFO]: Preparing level "world"
# [00:54:08 INFO]: [SkinsRestorer] ----------------------------------------------
# [00:54:08 INFO]: [SkinsRestorer]     +==================+
# [00:54:08 INFO]: [SkinsRestorer]     |   SkinsRestorer  |
# [00:54:08 INFO]: [SkinsRestorer]     |------------------|
# [00:54:08 INFO]: [SkinsRestorer]     |  Standalone Mode |
# [00:54:08 INFO]: [SkinsRestorer]     +==================+
# [00:54:08 INFO]: [SkinsRestorer] ----------------------------------------------
# [00:54:08 INFO]: [SkinsRestorer]     Version: 15.0.13
# [00:54:08 INFO]: [SkinsRestorer]     Commit: 8e4c6e2
# [00:54:08 INFO]: [SkinsRestorer]     This is the latest version!
# [00:54:08 INFO]: [SkinsRestorer] ----------------------------------------------
# [00:54:10 INFO]: Preparing start region for dimension minecraft:overworld
# [00:54:11 INFO]: Time elapsed: 1086 ms
# [00:54:11 INFO]: Preparing start region for dimension minecraft:the_nether
# [00:54:12 INFO]: Time elapsed: 444 ms
# [00:54:12 INFO]: Preparing start region for dimension minecraft:the_end
# [00:54:12 INFO]: Time elapsed: 147 ms
# [00:54:12 INFO]: [ViaVersion] Enabling ViaVersion v4.10.2
# [00:54:12 INFO]: [ViaVersion] ViaVersion detected server version: 1.20.3-1.20.4 (765)
# [00:54:12 INFO]: [floodgate] Enabling floodgate v2.2.3-SNAPSHOT (b107-c4a4487)
# [00:54:14 INFO]: [ViaBackwards] Enabling ViaBackwards v4.10.2
# [00:54:14 INFO]: [playit-gg] Enabling playit-gg v0.1.4
# [00:54:15 INFO]: [gg.playit.minecraft.PlayitKeysSetup] secret key found, checking
# [00:54:15 INFO]: [gg.playit.minecraft.PlayitKeysSetup] check secret
# [00:54:15 INFO]: [FastChunkPregenerator] Enabling FastChunkPregenerator v2.0.9-SNAPSHOT
# [00:54:16 INFO]: [FastChunkPregenerator] >> Paper was found.
# [00:54:16 INFO]: [FastChunkPregenerator] >> Async chunk loading support is enabled.
# [00:54:17 INFO]: [gg.playit.minecraft.PlayitKeysSetup] found minecraft java tunnel: digital-powell.joinmc.link
# [00:54:17 INFO]: [gg.playit.minecraft.PlayitManager] keys and tunnel setup
# [00:54:17 INFO]: [gg.playit.control.ChannelSetup] request queued, waiting 1 second before resend
# [00:54:18 INFO]: [GriefPrevention] Enabling GriefPrevention v16.18.3
# [00:54:18 INFO]: [GriefPrevention] Finished loading configuration.
# [00:54:18 INFO]: [GriefPrevention] 1 total claims loaded.
# [00:54:18 INFO]: [GriefPrevention] Customizable messages loaded.
# [00:54:18 INFO]: [GriefPrevention] Finished loading data (File Mode).
# [00:54:18 INFO]: [gg.playit.control.ChannelSetup] request queued, waiting 1 second before resend
# [00:54:18 INFO]: [GriefPrevention] Boot finished.
# [00:54:19 INFO]: [SetLobby] Enabling SetLobby v1.1*
# >....===[ SetLobby v1.1 by Ezreal_HD ]===
# Thanks for downloading SetLobby!
# Donate me: http://bit.ly/2OL2gJY=====================================
# [00:54:19 INFO]: [ClearLag] Enabling ClearLag v3.2.2
# [00:54:19 INFO]: [ClearLag] Using version-adapter: LatestVersionAdapter
# [00:54:19 INFO]: [ClearLag] Loading modules...
# [00:54:19 WARN]: [ClearLag] Clearlag failed to use the internal TPS tracker during initialization. Reverted to estimation... (net.minecraft.server.v1_20_R3.MinecraftServer)
# [00:54:19 INFO]: [ClearLag] Modules enabed, loading config values
# [00:54:19 INFO]: [ClearLag] Modules have been loaded!
# [00:54:19 INFO]: [ClearLag] Clearlag is now enabled!
# [00:54:19 INFO]: [SimpleTpa] Enabling SimpleTpa v7.0
# [00:54:19 INFO]: [ClearLag] Checking for updates compatible with your bukkit version [1.20]...
# [00:54:19 INFO]: [SimpleTpa] If you need support contact me at https://discord.gg/SZUkza9
# [00:54:19 INFO]: [SimpleTpa] Simple Tpa has been enabled on version 7.0
# [00:54:19 INFO]: Enabled metrics. You may opt-out by changing plugins/bStats/config.yml
# [00:54:19 INFO]: [Geyser-Spigot] Enabling Geyser-Spigot v2.3.1-SNAPSHOT
# [00:54:19 INFO]: [ClearLag] No updates found!
# [00:54:20 INFO]: [Geyser-Spigot] ******************************************
# [00:54:20 INFO]: [Geyser-Spigot]
# [00:54:20 INFO]: [Geyser-Spigot] Loading Geyser version 2.3.1-SNAPSHOT (git-master-66f30a2)
# [00:54:20 INFO]: [Geyser-Spigot]
# [00:54:20 INFO]: [Geyser-Spigot] ******************************************
# [00:54:46 INFO]: [Geyser-Spigot] Started Geyser on 0.0.0.0:22432
# [00:54:46 INFO]: [Geyser-Spigot] Done (26.786s)! Run /geyser help for help!
# [00:54:47 INFO]: Running delayed init tasks
# [00:54:47 INFO]: [world] Generating Chunks: 38823 of 376009 [10.41%] with [1.47 Chunks/s]
# [00:54:47 INFO]: [ViaVersion] Finished mapping loading, shutting down loader executor!
# [00:54:48 INFO]: Done (67.138s)! For help, type "help"
# [00:54:48 INFO]: Timings Reset
# [00:54:50 WARN]: Can't keep up! Is the server overloaded? Running 3010ms or 60 ticks behind
# [00:54:55 INFO]: [world] Generating Chunks: 39258 of 376009 [10.53%] with [51.76 Chunks/s]
# [00:55:03 INFO]: [world] Generating Chunks: 39685 of 376009 [10.65%] with [53.12 Chunks/s]
# [00:55:11 INFO]: [world] Generating Chunks: 39685 of 376009 [10.65%] with [0.0 Chunks/s]
# [00:55:19 INFO]: [world] Generating Chunks: 39688 of 376009 [10.65%] with [0.36 Chunks/s]
# [00:55:20 WARN]: Can't keep up! Is the server overloaded? Running 14850ms or 297 ticks behind
# [00:55:27 INFO]: [world] Generating Chunks: 39704 of 376009 [10.66%] with [1.99 Chunks/s]
# [00:55:35 INFO]: [world] Generating Chunks: 39718 of 376009 [10.66%] with [1.74 Chunks/s]
# [00:55:43 INFO]: [world] Generating Chunks: 39718 of 376009 [10.66%] with [0.0 Chunks/s]
# [00:55:51 INFO]: [world] Generating Chunks: 39720 of 376009 [10.66%] with [0.24 Chunks/s]
# [00:55:59 INFO]: [world] Generating Chunks: 39731 of 376009 [10.66%] with [1.36 Chunks/s]
# [00:56:03 WARN]: Can't keep up! Is the server overloaded? Running 3256ms or 65 ticks behind
# [00:56:07 INFO]: [world] Generating Chunks: 39767 of 376009 [10.67%] with [4.48 Chunks/s]
# [00:56:15 INFO]: [world] Generating Chunks: 39771 of 376009 [10.67%] with [0.49 Chunks/s]
# [00:56:23 INFO]: [world] Generating Chunks: 39785 of 376009 [10.68%] with [1.74 Chunks/s]
# [00:56:31 INFO]: [world] Generating Chunks: 39985 of 376009 [10.73%] with [24.93 Chunks/s]
# [00:56:39 INFO]: [world] Generating Chunks: 40049 of 376009 [10.75%] with [7.97 Chunks/s]
# [00:56:48 INFO]: [world] Generating Chunks: 40746 of 376009 [10.93%] with [86.74 Chunks/s]
# [00:56:56 INFO]: [world] Generating Chunks: 40746 of 376009 [10.93%] with [0.0 Chunks/s]
# [00:57:04 INFO]: [world] Generating Chunks: 40779 of 376009 [10.94%] with [4.12 Chunks/s]
# [00:57:12 INFO]: [world] Generating Chunks: 40779 of 376009 [10.94%] with [0.0 Chunks/s]
# [00:57:20 INFO]: [world] Generating Chunks: 40856 of 376009 [10.96%] with [9.62 Chunks/s]
# [00:57:28 INFO]: [world] Generating Chunks: 40923 of 376009 [10.98%] with [8.33 Chunks/s]
# [00:57:36 INFO]: [world] Generating Chunks: 41762 of 376009 [11.2%] with [104.69 Chunks/s]
# [00:57:44 INFO]: [world] Generating Chunks: 41813 of 376009 [11.22%] with [6.34 Chunks/s]
# [00:57:52 INFO]: [world] Generating Chunks: 41815 of 376009 [11.22%] with [0.24 Chunks/s]
# [00:58:00 INFO]: [world] Generating Chunks: 41900 of 376009 [11.24%] with [10.59 Chunks/s]
# [00:58:08 INFO]: [world] Generating Chunks: 41906 of 376009 [11.24%] with [0.74 Chunks/s]
# [00:58:16 INFO]: [world] Generating Chunks: 42514 of 376009 [11.4%] with [75.94 Chunks/s]
# [00:58:20 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [00:58:24 INFO]: [world] Generating Chunks: 42852 of 376009 [11.49%] with [42.01 Chunks/s]
# >....

# %% [markdown]
# **FAQ - THINGS YOU NEED TO KNOW**
#
# Google Colab is not intended for creating Minecraft servers, but it can be done. Google Colab promises to work continuously for 12 hours; however, it may close if there is no one actively reviewing the page or using the console. In essence, if the page detects inactivity, the process will terminate. The performance is approximately 12 GB of RAM, along with a processor with a speed of 2.2 GHz and 2 threads. This is better than many paid hosting services, but it lacks support and does not guarantee to be open all the time. Mods can be installed, but it is not advisable to overload it with too many, just like plugins. The primary limitation of this server is its processor, which is not very powerful. Any hosting for $12 can offer a server of higher quality. If you plan to create something for many users, using a dedicated hosting service is much better. The servers used are from Google along with the Ngrok proxy.
